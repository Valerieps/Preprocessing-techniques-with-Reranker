# %% [markdown]
# # Prepare Environment

# %%
# %%capture
# !pip install ipython-autotime
# %load_ext autotime

# %cd /content/drive/MyDrive/__TCC__Reranker/Reranker
# %pip install -e .
# Out:
# time: 1min 49s (started: 2021-09-05 01:40:31 +00:00)

# %% [markdown]
# # Preprocessa

# %%
#!bash /content/drive/MyDrive/__TCC__Reranker/Reranker/run_summarization/scripts/run_preprocess.sh
# Out:
# time: 1.04 ms (started: 2021-09-03 06:44:56 +00:00)

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/run_summarization/scripts/1_preprocess_fixed_summarization.py \
#     --tokenizer_name bert-base-uncased \
#     --rank_file 	/content/drive/MyDrive/__TCC__Reranker/Reranker/common_data/01-hdct-marco-train/000.txt \
#     --json_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_summarization/data/1-training_files \
#     --n_sample 10 \
#     --sample_from_top 100 \
#     --random \
#     --truncate 512 \
#     --qrel /content/drive/MyDrive/__TCC__Reranker/Reranker/common_data/02-msmarco-files/msmarco-doctrain-qrels.tsv.gz \
#     --query_collection /content/drive/MyDrive/__TCC__Reranker/Reranker/common_data/02-msmarco-files/msmarco-doctrain-queries.tsv \
#     --doc_collection /content/drive/MyDrive/__TCC__Reranker/Reranker/common_data/02-msmarco-files/msmarco-docs.tsv
# Out:
# time: 1.46 ms (started: 2021-08-30 22:59:44 +00:00)

# %% [markdown]
# # Realiza treino on 6 seeds

# %%
# vai realizar treino cmo 1 files. Os outrso 9 estão em outra pasta
# retreinando pq antes trcou a gpu e ficou um lixo
# !python -m torch.distributed.launch \
  --nproc_per_node 1 /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/run_marco_original.py \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_1028 \
  --model_name_or_path  bert-base-uncased \
  --do_train \
  --save_steps 2000 \
  --train_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/training-files/ \
  --max_len 512 \
  --fp16 \
  --per_device_train_batch_size 1 \
  --train_group_size 8 \
  --gradient_accumulation_steps 1 \
  --per_device_eval_batch_size 64 \
  --warmup_ratio 0.1 \
  --weight_decay 0.01 \
  --learning_rate 1e-5 \
  --num_train_epochs 2 \
  --overwrite_output_dir \
  --dataloader_num_workers 8 \
  --seed 1028
# Out:
# 09/05/2021 01:42:30 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, 16-bits training: True
# ...

# %%
# !python -m torch.distributed.launch \
  --nproc_per_node 1 /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/run_marco_original.py \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_061 \
  --model_name_or_path  bert-base-uncased \
  --do_train \
  --save_steps 2000 \
  --train_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/training-files/ \
  --max_len 512 \
  --fp16 \
  --per_device_train_batch_size 1 \
  --train_group_size 8 \
  --gradient_accumulation_steps 1 \
  --per_device_eval_batch_size 64 \
  --warmup_ratio 0.1 \
  --weight_decay 0.01 \
  --learning_rate 1e-5 \
  --num_train_epochs 2 \
  --overwrite_output_dir \
  --dataloader_num_workers 8 \
  --seed 061
# Out:
# 09/05/2021 02:08:38 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, 16-bits training: True
# ...

# %%
# !python -m torch.distributed.launch \
  --nproc_per_node 1 /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/run_marco_original.py \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_280 \
  --model_name_or_path  bert-base-uncased \
  --do_train \
  --save_steps 2000 \
  --train_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/training-files/ \
  --max_len 512 \
  --fp16 \
  --per_device_train_batch_size 1 \
  --train_group_size 8 \
  --gradient_accumulation_steps 1 \
  --per_device_eval_batch_size 64 \
  --warmup_ratio 0.1 \
  --weight_decay 0.01 \
  --learning_rate 1e-5 \
  --num_train_epochs 2 \
  --overwrite_output_dir \
  --dataloader_num_workers 8 \
  --seed 280
# Out:
# 09/05/2021 02:35:19 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, 16-bits training: True
# ...

# %%
# !python -m torch.distributed.launch \
  --nproc_per_node 1 /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/run_marco_original.py \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_666 \
  --model_name_or_path  bert-base-uncased \
  --do_train \
  --save_steps 2000 \
  --train_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/training-files/ \
  --max_len 512 \
  --fp16 \
  --per_device_train_batch_size 1 \
  --train_group_size 8 \
  --gradient_accumulation_steps 1 \
  --per_device_eval_batch_size 64 \
  --warmup_ratio 0.1 \
  --weight_decay 0.01 \
  --learning_rate 1e-5 \
  --num_train_epochs 2 \
  --overwrite_output_dir \
  --dataloader_num_workers 8 \
  --seed 666
# Out:
# 09/05/2021 03:02:06 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, 16-bits training: True
# ...

# %%
# !python -m torch.distributed.launch \
  --nproc_per_node 1 /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/run_marco_original.py \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_974 \
  --model_name_or_path  bert-base-uncased \
  --do_train \
  --save_steps 2000 \
  --train_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/training-files/ \
  --max_len 512 \
  --fp16 \
  --per_device_train_batch_size 1 \
  --train_group_size 8 \
  --gradient_accumulation_steps 1 \
  --per_device_eval_batch_size 64 \
  --warmup_ratio 0.1 \
  --weight_decay 0.01 \
  --learning_rate 1e-5 \
  --num_train_epochs 2 \
  --overwrite_output_dir \
  --dataloader_num_workers 8 \
  --seed 974
# Out:
# 09/05/2021 03:28:55 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, 16-bits training: True
# ...

# %%
# !python -m torch.distributed.launch \
  --nproc_per_node 1 /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/run_marco_original.py \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_999 \
  --model_name_or_path  bert-base-uncased \
  --do_train \
  --save_steps 2000 \
  --train_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/training-files/ \
  --max_len 512 \
  --fp16 \
  --per_device_train_batch_size 1 \
  --train_group_size 8 \
  --gradient_accumulation_steps 1 \
  --per_device_eval_batch_size 64 \
  --warmup_ratio 0.1 \
  --weight_decay 0.01 \
  --learning_rate 1e-5 \
  --num_train_epochs 2 \
  --overwrite_output_dir \
  --dataloader_num_workers 8 \
  --seed 999
# Out:
# 09/05/2021 03:55:36 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, 16-bits training: True
# ...

# %% [markdown]
# # Realiza Inference Fixed

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py \
  --model_name_or_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_1028 \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval \
  --tokenizer_name bert-base-uncased \
  --do_predict \
  --max_len 512 \
  --fp16 \
  --per_device_eval_batch_size 64 \
  --dataloader_num_workers 8 \
  --pred_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_all.json \
  --pred_id_file  /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_ids.tsv \
  --rank_score_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_1028.txt
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAa
#
# ...
#
# =========== CONFIGURANDO AS COISAS ===========
#
# ...
# /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_1028
#
# ===========  GETTING DATASET ===========
#
# ===========  INITIALIZING TRAINER ===========
#
# ===========  PREDICTION ===========
# Using custom data configuration default
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 217, in <module>
#     main()
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 170, in main
#     max_len=data_args.max_len,
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/src/reranker/data.py", line 115, in __init__
#     data_files=path_to_json,
#   File "/usr/local/lib/python3.7/dist-packages/datasets/load.py", line 603, in load_dataset
#     **config_kwargs,
# ...

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py \
  --model_name_or_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_061 \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval \
  --tokenizer_name bert-base-uncased \
  --do_predict \
  --max_len 512 \
  --fp16 \
  --per_device_eval_batch_size 64 \
  --dataloader_num_workers 8 \
  --pred_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_all.json \
  --pred_id_file  /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_ids.tsv \
  --rank_score_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_061.txt
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAa
#
# ...
#
# =========== CONFIGURANDO AS COISAS ===========
#
# ...
# /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_061
#
# ===========  GETTING DATASET ===========
#
# ===========  INITIALIZING TRAINER ===========
#
# ===========  PREDICTION ===========
# Using custom data configuration default
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 217, in <module>
#     main()
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 170, in main
#     max_len=data_args.max_len,
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/src/reranker/data.py", line 115, in __init__
#     data_files=path_to_json,
#   File "/usr/local/lib/python3.7/dist-packages/datasets/load.py", line 603, in load_dataset
#     **config_kwargs,
# ...

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py \
  --model_name_or_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_280 \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval \
  --tokenizer_name bert-base-uncased \
  --do_predict \
  --max_len 512 \
  --fp16 \
  --per_device_eval_batch_size 64 \
  --dataloader_num_workers 8 \
  --pred_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_all.json \
  --pred_id_file  /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_ids.tsv \
  --rank_score_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_280.txt
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAa
#
# ...
#
# =========== CONFIGURANDO AS COISAS ===========
#
# ...
# /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_280
#
# ===========  GETTING DATASET ===========
#
# ===========  INITIALIZING TRAINER ===========
#
# ===========  PREDICTION ===========
# Using custom data configuration default
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 217, in <module>
#     main()
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 170, in main
#     max_len=data_args.max_len,
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/src/reranker/data.py", line 115, in __init__
#     data_files=path_to_json,
#   File "/usr/local/lib/python3.7/dist-packages/datasets/load.py", line 603, in load_dataset
#     **config_kwargs,
# ...

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py \
  --model_name_or_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_666 \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval \
  --tokenizer_name bert-base-uncased \
  --do_predict \
  --max_len 512 \
  --fp16 \
  --per_device_eval_batch_size 64 \
  --dataloader_num_workers 8 \
  --pred_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_all.json \
  --pred_id_file  /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_ids.tsv \
  --rank_score_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_666.txt
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAa
#
# ...
#
# =========== CONFIGURANDO AS COISAS ===========
#
# ...
# /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_666
#
# ===========  GETTING DATASET ===========
#
# ===========  INITIALIZING TRAINER ===========
#
# ===========  PREDICTION ===========
# Using custom data configuration default
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 217, in <module>
#     main()
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 170, in main
#     max_len=data_args.max_len,
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/src/reranker/data.py", line 115, in __init__
#     data_files=path_to_json,
#   File "/usr/local/lib/python3.7/dist-packages/datasets/load.py", line 603, in load_dataset
#     **config_kwargs,
# ...

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py \
  --model_name_or_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_974 \
  --output_dir /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval \
  --tokenizer_name bert-base-uncased \
  --do_predict \
  --max_len 512 \
  --fp16 \
  --per_device_eval_batch_size 64 \
  --dataloader_num_workers 8 \
  --pred_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_all.json \
  --pred_id_file  /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/inference-files/mini_ids.tsv \
  --rank_score_path /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_974.txt
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAa
#
# ...
#
# =========== CONFIGURANDO AS COISAS ===========
#
# ...
# /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/checkpoints_974
#
# ===========  GETTING DATASET ===========
#
# ===========  INITIALIZING TRAINER ===========
#
# ===========  PREDICTION ===========
# Using custom data configuration default
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 217, in <module>
#     main()
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/2_run_marco.py", line 170, in main
#     max_len=data_args.max_len,
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/src/reranker/data.py", line 115, in __init__
#     data_files=path_to_json,
#   File "/usr/local/lib/python3.7/dist-packages/datasets/load.py", line 603, in load_dataset
#     **config_kwargs,
# ...

# %% [markdown]
# # Converte para MSmarco datafile Fixed

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py \
 --score_file /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_061.txt

# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py \
 --score_file /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_1028.txt

# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py \
 --score_file /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_280.txt

# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py \
 --score_file /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_666.txt

# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py \
 --score_file /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_974.txt
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py", line 14, in <module>
#     with open(args.score_file) as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_061.txt'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py", line 14, in <module>
#     with open(args.score_file) as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_1028.txt'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py", line 14, in <module>
#     with open(args.score_file) as f:
# ...

# %%
# !python /content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py \
 --score_file /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_1028.txt

# %% [markdown]
# # Avalia inference

# %%
# !bash /content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/scripts/run_5_evaluation.sh
# Out:
# \n================= 974 =================
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/4_score_to_marco.py", line 14, in <module>
#     with open(args.score_file) as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/__TCC__Reranker/Reranker/run_lsa_summarization/data/eval/score_974.txt'
# 398 excluded qids loaded
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/6_msmarco_eval_2.py", line 226, in <module>
#     main()
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/6_msmarco_eval_2.py", line 218, in main
#     metrics = compute_metrics_from_files(path_to_reference, path_to_candidate, exclude_qids)
#   File "/content/drive/MyDrive/__TCC__Reranker/Reranker/common_scripts/6_msmarco_eval_2.py", line 179, in compute_metrics_from_files
# ...
