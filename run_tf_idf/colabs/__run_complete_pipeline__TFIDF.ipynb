# %% [markdown]
# # Prepare environment

# %%
# %cd /content/drive/MyDrive/__TCC__Reranker/Reranker
# Out:
# time: 2.01 ms (started: 2021-09-05 13:33:59 +00:00)

# %%
# %%capture
# !pip install ipython-autotime
# !pip install -e .
# !pip install pandas
# !pip install nltk

# %%
import nltk
nltk.download("punkt", quiet=True)
nltk.download("stopwords", quiet=True)

# %%
# %load_ext autotime

# %%
# !nvidia-smi
# Out:
# Sun Sep  5 13:33:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Preprocessa arquivos de treino

# %%
# !bash /content/drive/MyDrive/__TCC__Reranker/Reranker/run_tf_idf/scripts/run_preprocess_to_train.sh

# %% [markdown]
# # Realiza treino

# %%
# !bash /content/drive/MyDrive/__TCC__Reranker/Reranker/run_tf_idf/scripts/run_5_train.sh

# %% [markdown]
# # Preprocessa arquivos de eval

# %%
# !bash /content/drive/MyDrive/__TCC__Reranker/Reranker/run_tf_idf/scripts/run_preprocess_to_eval.sh

# %% [markdown]
# # Realiza Inference on five checkpoints

# %%
# !bash /content/drive/MyDrive/__TCC__Reranker/Reranker/run_tf_idf/scripts/run_5_inference.sh

# %% [markdown]
# # Run evaluation on the five scores

# %%
# !bash /content/drive/MyDrive/__TCC__Reranker/Reranker/run_tf_idf/scripts/run_5_evaluation.sh
